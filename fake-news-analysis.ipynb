# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/fake-news-prediction/fake_news_with_prediction.csv
# /kaggle/input/fake-news-prediction/fake_news3_with_prediction.csv
# /kaggle/input/fake-news-prediction/fake_news1_with_prediction.csv
# /kaggle/input/fake-news-prediction/fake_news2_with_prediction.csv

# %%
fake_news=pd.read_csv("/kaggle/input/fake-news-prediction/fake_news_with_prediction.csv")
fake_news
# Out:
#                                                     text  label  \
# 0      dark agenda behind globalism open border altma...      0
# 1      america poor still get shaft sami jamil jadall...      0
# 2      number accuser grow former miss finland accuse...      0
# 3      heroic prego advertisement replaces refresh we...      0
# 4      russia syria debbie reynolds thursday even bri...      1
# ...                                                  ...    ...
# 16641  comment cost selfdriving taxi really sixtyseve...      0
# 16642  interest duterte get billion china get money j...      0
# 16643  forget encyclopaedia get pokiespedia home win ...      0
# 16644  u election race huma abedin connection minute ...      0
# 16645  shameful obama legacy white man beat viciously...      0
#
#       Predicted Emotion
# 0               neutral
# 1               neutral
# 2               neutral
# 3               neutral
# 4               neutral
# ...                 ...
# ...

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
fake_news = pd.read_csv("/kaggle/input/fake-news-prediction/fake_news_with_prediction.csv")

# Define the emotions
emotions = ['anger', 'boredom', 'empty', 'enthusiasm', 'fun', 'happiness', 
            'hate', 'love', 'neutral', 'relief', 'sadness', 'surprise', 'worry']

# Filter data by label
df_label_1 = fake_news[fake_news['label'] == 1]
df_label_0 = fake_news[fake_news['label'] == 0]

# Count emotions for each label
emotion_counts_label_1 = df_label_1['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)
emotion_counts_label_0 = df_label_0['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)

# Plotting
x = np.arange(len(emotions))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, emotion_counts_label_0, width, label='Label 0')
bars2 = ax.bar(x + width/2, emotion_counts_label_1, width, label='Label 1')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Emotions')
ax.set_ylabel('Counts')
ax.set_title('Emotion Distribution by Fake News Label')
ax.set_xticks(x)
ax.set_xticklabels(emotions, rotation=45)
ax.legend()

# Add counts on top of bars
def add_counts(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_counts(bars1)
add_counts(bars2)

plt.tight_layout()
plt.show()

# %%
# import pandas as pd
# import matplotlib.pyplot as plt

# # Load the dataset
# fake_news = pd.read_csv("/kaggle/input/fake-news-prediction/fake_news_with_prediction.csv")

# # List of emotions to compare
# emotions = ['anger', 'boredom', 'empty', 'enthusiasm', 'fun', 'happiness', 'hate', 'love', 'neutral', 'relief', 'sadness', 'surprise', 'worry']

# # Initialize a list to hold emotion counts
# emotion_counts_list = []

# # Count the occurrences of each emotion in fake and real news
# for emotion in emotions:
#     fake_count = fake_news[(fake_news['label'] == 1) & (fake_news['Predicted Emotion'] == emotion)].shape[0]
#     real_count = fake_news[(fake_news['label'] == 0) & (fake_news['Predicted Emotion'] == emotion)].shape[0]
#     emotion_counts_list.append({'emotion': emotion, 'fake': fake_count, 'real': real_count})

# # Convert the list to a DataFrame
# emotion_counts = pd.DataFrame(emotion_counts_list)

# # Plot the comparison of emotions
# emotion_counts.set_index('emotion').plot(kind='bar', stacked=True, color=['red', 'green'], alpha=0.7, figsize=(12, 8))
# plt.title('Comparison of Emotions in Fake vs Real News')
# plt.xlabel('Emotion')
# plt.ylabel('Count')
# plt.legend(['Fake', 'Real'])
# plt.show()

# %%
# Load the dataset
fake_news1 = pd.read_csv("/kaggle/input/fake-news-prediction/fake_news1_with_prediction.csv")

# Define the emotions
emotions = ['anger', 'boredom', 'empty', 'enthusiasm', 'fun', 'happiness', 
            'hate', 'love', 'neutral', 'relief', 'sadness', 'surprise', 'worry']

# Filter data by label
df_label_1 = fake_news1[fake_news1['label'] == 1]
df_label_0 = fake_news1[fake_news1['label'] == 0]

# Count emotions for each label
emotion_counts_label_1 = df_label_1['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)
emotion_counts_label_0 = df_label_0['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)

# Plotting
x = np.arange(len(emotions))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, emotion_counts_label_0, width, label='Label 0')
bars2 = ax.bar(x + width/2, emotion_counts_label_1, width, label='Label 1')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Emotions')
ax.set_ylabel('Counts')
ax.set_title('Emotion Distribution by Fake News Label')
ax.set_xticks(x)
ax.set_xticklabels(emotions, rotation=45)
ax.legend()

# Add counts on top of bars
def add_counts(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_counts(bars1)
add_counts(bars2)

plt.tight_layout()
plt.show()

# %%
# Load the dataset
fake_news2 = pd.read_csv("/kaggle/input/fake-news-prediction/fake_news2_with_prediction.csv")

# Define the emotions
emotions = ['anger', 'boredom', 'empty', 'enthusiasm', 'fun', 'happiness', 
            'hate', 'love', 'neutral', 'relief', 'sadness', 'surprise', 'worry']

# Filter data by label
df_label_1 = fake_news2[fake_news2['label'] == 1]
df_label_0 = fake_news2[fake_news2['label'] == 0]

# Count emotions for each label
emotion_counts_label_1 = df_label_1['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)
emotion_counts_label_0 = df_label_0['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)

# Plotting
x = np.arange(len(emotions))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, emotion_counts_label_0, width, label='Label 0')
bars2 = ax.bar(x + width/2, emotion_counts_label_1, width, label='Label 1')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Emotions')
ax.set_ylabel('Counts')
ax.set_title('Emotion Distribution by Fake News Label')
ax.set_xticks(x)
ax.set_xticklabels(emotions, rotation=45)
ax.legend()

# Add counts on top of bars
def add_counts(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_counts(bars1)
add_counts(bars2)

plt.tight_layout()
plt.show()

# %%
# Load the dataset
fake_news3 = pd.read_csv("/kaggle/input/fake-news-prediction/fake_news3_with_prediction.csv")

# Define the emotions
emotions = ['anger', 'boredom', 'empty', 'enthusiasm', 'fun', 'happiness', 
            'hate', 'love', 'neutral', 'relief', 'sadness', 'surprise', 'worry']

# Filter data by label
df_label_1 = fake_news3[fake_news3['label'] == 1]
df_label_0 = fake_news3[fake_news3['label'] == 0]

# Count emotions for each label
emotion_counts_label_1 = df_label_1['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)
emotion_counts_label_0 = df_label_0['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)

# Plotting
x = np.arange(len(emotions))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, emotion_counts_label_0, width, label='Label 0')
bars2 = ax.bar(x + width/2, emotion_counts_label_1, width, label='Label 1')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Emotions')
ax.set_ylabel('Counts')
ax.set_title('Emotion Distribution by Fake News Label')
ax.set_xticks(x)
ax.set_xticklabels(emotions, rotation=45)
ax.legend()

# Add counts on top of bars
def add_counts(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_counts(bars1)
add_counts(bars2)

plt.tight_layout()
plt.show()

# %%
fake_news['label'].value_counts()
# Out:
# label
# 0    8323
# 1    8323
# Name: count, dtype: int64

# %%
fake_news1 = pd.read_csv("/kaggle/input/fake-news-prediction/fake_news1_with_prediction.csv")

# %%
fake_news1['label'].value_counts()
# Out:
# label
# 0    18266
# 1    18266
# Name: count, dtype: int64

# %%
fake_news3 = pd.read_csv("/kaggle/input/fake-news-prediction/fake_news3_with_prediction.csv")

# %%
fake_news3['label'].value_counts()
# Out:
# label
# 0    2536
# 1    2536
# Name: count, dtype: int64

# %%
fake_news2 = pd.read_csv("/kaggle/input/fake-news-prediction/fake_news2_with_prediction.csv")

# %%
fake_news2['label'].value_counts()
# Out:
# label
# 0    1670
# 1    1670
# Name: count, dtype: int64

# %% [markdown]
# # NEUTRAL REDUCED

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
fake_news = pd.read_csv("/kaggle/input/fake-news-emotion-detection-neutral/fake_news_with_prediction_neutral.csv")

# Define the emotions
emotions = ['anger', 'boredom', 'empty', 'enthusiasm', 'fun', 'happiness', 
            'hate', 'love', 'neutral', 'relief', 'sadness', 'surprise', 'worry']

# Filter data by label
df_label_1 = fake_news[fake_news['label'] == 1]
df_label_0 = fake_news[fake_news['label'] == 0]

# Count emotions for each label
emotion_counts_label_1 = df_label_1['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)
emotion_counts_label_0 = df_label_0['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)

# Plotting
x = np.arange(len(emotions))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, emotion_counts_label_0, width, label='Label 0')
bars2 = ax.bar(x + width/2, emotion_counts_label_1, width, label='Label 1')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Emotions')
ax.set_ylabel('Counts')
ax.set_title('Emotion Distribution by Fake News Label')
ax.set_xticks(x)
ax.set_xticklabels(emotions, rotation=45)
ax.legend()

# Add counts on top of bars
def add_counts(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_counts(bars1)
add_counts(bars2)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
fake_news1_neu = pd.read_csv("/kaggle/input/fake-news-emotion-detection-neutral/fake_news1_with_prediction_neutral.csv")

# Define the emotions
emotions = ['anger', 'boredom', 'empty', 'enthusiasm', 'fun', 'happiness', 
            'hate', 'love', 'neutral', 'relief', 'sadness', 'surprise', 'worry']

# Filter data by label
df_label_1 = fake_news1_neu[fake_news1_neu['label'] == 1]
df_label_0 = fake_news1_neu[fake_news1_neu['label'] == 0]

# Count emotions for each label
emotion_counts_label_1 = df_label_1['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)
emotion_counts_label_0 = df_label_0['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)

# Plotting
x = np.arange(len(emotions))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, emotion_counts_label_0, width, label='Label 0')
bars2 = ax.bar(x + width/2, emotion_counts_label_1, width, label='Label 1')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Emotions')
ax.set_ylabel('Counts')
ax.set_title('Emotion Distribution by Fake News Label')
ax.set_xticks(x)
ax.set_xticklabels(emotions, rotation=45)
ax.legend()

# Add counts on top of bars
def add_counts(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_counts(bars1)
add_counts(bars2)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
fake_news2_neu = pd.read_csv("/kaggle/input/fake-news-emotion-detection-neutral/fake_news2_with_prediction_neutral.csv")

# Define the emotions
emotions = ['anger', 'boredom', 'empty', 'enthusiasm', 'fun', 'happiness', 
            'hate', 'love', 'neutral', 'relief', 'sadness', 'surprise', 'worry']

# Filter data by label
df_label_1 = fake_news2_neu[fake_news2_neu['label'] == 1]
df_label_0 = fake_news2_neu[fake_news2_neu['label'] == 0]

# Count emotions for each label
emotion_counts_label_1 = df_label_1['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)
emotion_counts_label_0 = df_label_0['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)

# Plotting
x = np.arange(len(emotions))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, emotion_counts_label_0, width, label='Label 0')
bars2 = ax.bar(x + width/2, emotion_counts_label_1, width, label='Label 1')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Emotions')
ax.set_ylabel('Counts')
ax.set_title('Emotion Distribution by Fake News Label')
ax.set_xticks(x)
ax.set_xticklabels(emotions, rotation=45)
ax.legend()

# Add counts on top of bars
def add_counts(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_counts(bars1)
add_counts(bars2)

plt.tight_layout()
plt.show()

# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np

# Load the dataset
fake_news3_neu = pd.read_csv("/kaggle/input/fake-news-emotion-detection-neutral/fake_news3_with_prediction_neutral.csv")

# Define the emotions
emotions = ['anger', 'boredom', 'empty', 'enthusiasm', 'fun', 'happiness', 
            'hate', 'love', 'neutral', 'relief', 'sadness', 'surprise', 'worry']

# Filter data by label
df_label_1 = fake_news3_neu[fake_news3_neu['label'] == 1]
df_label_0 = fake_news3_neu[fake_news3_neu['label'] == 0]

# Count emotions for each label
emotion_counts_label_1 = df_label_1['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)
emotion_counts_label_0 = df_label_0['Predicted Emotion'].value_counts().reindex(emotions, fill_value=0)

# Plotting
x = np.arange(len(emotions))  # the label locations
width = 0.35  # the width of the bars

fig, ax = plt.subplots(figsize=(14, 8))

bars1 = ax.bar(x - width/2, emotion_counts_label_0, width, label='Label 0')
bars2 = ax.bar(x + width/2, emotion_counts_label_1, width, label='Label 1')

# Add some text for labels, title and custom x-axis tick labels, etc.
ax.set_xlabel('Emotions')
ax.set_ylabel('Counts')
ax.set_title('Emotion Distribution by Fake News Label')
ax.set_xticks(x)
ax.set_xticklabels(emotions, rotation=45)
ax.legend()

# Add counts on top of bars
def add_counts(bars):
    for bar in bars:
        height = bar.get_height()
        ax.annotate('{}'.format(height),
                    xy=(bar.get_x() + bar.get_width() / 2, height),
                    xytext=(0, 3),  # 3 points vertical offset
                    textcoords="offset points",
                    ha='center', va='bottom')

add_counts(bars1)
add_counts(bars2)

plt.tight_layout()
plt.show()
